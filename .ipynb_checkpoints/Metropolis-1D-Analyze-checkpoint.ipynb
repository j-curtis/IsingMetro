# %%
import numpy as np
import matplotlib.pyplot as plt
import Metropolis1D as m1d
import Simulate1D as s1d

# %%
"""Parameters"""
L = 128 #Lattice Size
J = 2.0 #Spin Coupling 
h = -0.25 #External Field 
nSteps = 128*128 #The number of steps we use to simulate the lattice

# %%
"""Run the simulation"""
sim = s1d.Simulation(L,J,h,nSteps)
sim.simulate()

# %%
"""Plot Energy"""
plt.plot(sim.energy)

plt.xlim(0,nSteps)

plt.title("Energy/site vs. Time")
plt.xlabel("Time (steps)")
plt.ylabel("Energy per site (unitless)")
#plt.text(nSteps/2,-.2,"L=%s\nJ=%s\nh=%s"%(L,J,h))

plt.show()

# %%
"""Plot Magnetization"""
plt.plot(sim.mag)
plt.axhline(color="red")

plt.ylim(-1.0,1.0)
plt.xlim(0,nSteps)

plt.title("Magnetization/site vs. Time")
plt.xlabel("Time (steps)")
plt.ylabel("Magnetization per site (unitless)")
plt.text(nSteps/2,.5,"L=%s\nJ=%s\nh=%s"%(L,J,h))

plt.show()

# %%
"""Plot Nearest-Neighbor Correlation"""
plt.plot(sim.pair)
plt.axhline(color="red")

plt.ylim(-1.0,1.0)
plt.xlim(0,nSteps)

plt.title("NN Pair Correlation/site vs. Time")
plt.xlabel("Time (steps)")
plt.ylabel("Pair Correlation per site (unitless)")
plt.text(nSteps/2,.5,"L=%s\nJ=%s\nh=%s"%(L,J,h))

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-95c689aa2079> in <module>()
#       1 """Plots"""
#       2 image = np.zeros(shape=(nSteps,L,3))
# ----> 3 image[state_timeseries==1.0] = [0,0,0]
#       4 image[state_timeseries==-1.0] = [1,1,1]
#       5
#
# NameError: name 'state_timeseries' is not defined
